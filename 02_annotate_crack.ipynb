# %%
# Load your frames

import numpy as np
import napari

frames = np.load('processed/30nm/0924 20240626 Camera 220 kx 0001.npy', mmap_mode='r')
# Select frames to annotate with uniform spacing across the full sequence
# Target roughly 50 annotated frames regardless of sequence length

n_frames = frames.shape[0]
step = max(1, int(np.ceil(n_frames / 50)))
frames_to_annotate = list(range(0, n_frames, step))
frames_subset = frames[frames_to_annotate]

# Launch napari
viewer = napari.Viewer()
viewer.add_image(frames_subset, name='TEM frames', colormap='gray')
labels = viewer.add_labels(np.zeros(frames_subset.shape, dtype=np.uint8), name='crack_masks')

napari.run()  # Opens GUI window
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x653+960+456 (frame: 1104x700+951+418) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1360x818+961+463 (frame: 1378x865+952+425) margins: 9, 38, 9, 9 minimum size: 385x505 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=403,552 maxtrack=0,0)

# %%
# Extract annotations from the napari labels layer
masks = labels.data

# Your data file name (without extension)
sample_name = "0924 20240626 Camera 220 kx 0001"

# Save with descriptive names to the annotations folder
np.save(f'annotations/30nm/{sample_name}_annotated_masks.npy', masks)
np.save(f'annotations/30nm/{sample_name}_frame_indices.npy', np.array(frames_to_annotate))
